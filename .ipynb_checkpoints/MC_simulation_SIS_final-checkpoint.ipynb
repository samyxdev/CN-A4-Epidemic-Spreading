# %% [markdown]
# # Monte Carlo simulation of SIS epidemic spreading
# Monte Carlo simulation of an epidemic spreading dynamics in complex networks, using the SIS model in which each node represents an individual which can be in two possible states: Susceptible (S), i.e., healthy but can get infected; Infected (I), i.e., has the disease and can spread it to its neighbors. <br><br>
#
# We are interested in the calculation of the fraction of infected nodes, ρ, in the stationary state, as a function of the infection probability of the disease β (at least 51 values between β=0 and β=1, Δβ=0.02), for different values of the recovery probability μ (e.g. 0.1, 0.5, 0.9).

# %% [markdown]
# ### Import libraries

# %%
# !pip install igraph
import igraph as ig
import numpy as np
import time
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-darkgrid')
plt.rcParams["figure.figsize"] = (12, 6)

# import cython module for allowing c compilation and static binding to improve the performance
# %load_ext cython
# Out:
# Requirement already satisfied: igraph in c:\users\denal\anaconda3\lib\site-packages (0.9.9)
# Requirement already satisfied: texttable>=1.6.2 in c:\users\denal\anaconda3\lib\site-packages (from igraph) (1.6.4)
# The cython extension is already loaded. To reload it, use:
#   %reload_ext cython

# %% [markdown]
# Be sure to insall the Cython extension!

# %% [markdown]
# ## Auxiliary functions

# %% [markdown]
# ### Simulation function
# The function below performs 1 full simulation of SIS epidemic spreading. <br>
# Since this function is very expensive and it needs to be called at each performed simulation, we declare it as a c function and we add also some static binding for some of the used variables. <br>
# In this way we greatly improve the performance of the algorithm. <br><br>
# The simulation function takes in input:
# * the graph g and its length
# * the array of initial states (randomly generated): it is an array of the same size as the one of the network, where each cell indicates the state of the corresponding node (1 stands for I and 0 stands for S)
# * the 2 main paramters of the SIS model, i.e. µ and β
#
# The function performs TMAX iterations and it returns the average of ρ(t) calcualating considering the mean of the ρ values obtained after TTRANS iterations, when we assume that the systems has
# reached the stationary state. <br>
#
# Indeed, the simulation requires also 2 extra parameters:
# * TMAX  maximum number of time steps of each simulation
# * TTRANS  number of steps of the transitory

# %%
# %%cython
# import numpy as np
# import igraph as ig
# from libc.math cimport pow # import C pow function
# from libc.stdlib cimport rand, srand, RAND_MAX # import C random functions
# from libc.time cimport time,time_t # import C time function
#
# def simulation(g, int len_g, char[:] state, double mu, double beta):
#
#     """
#     Applies one simulation to the graph in argument and returns
#     the average infection rate over the stationary time steps
#     """
#
#     # Constants
#     cdef int TMAX = 1000 # maximum number of time steps of each simulation
#     cdef int TTRANS = 900 # number of steps of the transitory
#     cdef double _beta = 1 - beta
#
#     # Declared variables
#     cdef double[:] infected_ratio_list = np.zeros(TMAX - TTRANS) # infection ratio at each step of the stationary
#     cdef int i, j, v, n # counters
#     cdef int infected_vertices # number of infected neighbors
#     cdef char[:] old_state = np.zeros(len_g, dtype = np.int8) # array of the states of the nodes in the previous iteration
#     cdef double prob # probability value between 0 and 1
#     cdef double a = RAND_MAX
#     cdef int num_infected = 0 # counter of the number of infected vertices at each time step
#
#     # set random seed
#     srand(time(NULL))
#
#     #simulation loop
#     for i in range(TMAX):
#
#         if i >= TTRANS:
#             num_infected = 0
#
#         # copy old state
#         for j in range(len_g):
#             old_state[j] = state[j]
#
#         # update states of all nodes
#         for j in range(len_g):
#
#             # if old node state is I
#             if old_state[j]:
#                 prob = rand() / a # generate random number in [0, 1]
#                 if prob < mu: # update new state
#                     state[j] = 0
#                 else:
#                     state[j] = 1
#
#             # if old node state is S
#             else:
#                 infected_vertices = 0  # counter of the infected vertices of current SUSCECTIBLE node
#
#                 for n in g.neighbors(j):
#                     infected_vertices += old_state[n]
#                 prob = rand() / a
#                 if prob < pow(1 - beta, infected_vertices):
#                     state[j] = 0
#                 else:
#                     state[j] = 1
#
#             # we compute infection ratio from iteration 900
#             if i >= TTRANS:
#                 num_infected += state[j]
#
#         if i >= TTRANS:
#             infected_ratio_list[i - TTRANS] = num_infected/len_g
#
#     # returns the average infected ratio (calculated only over the stationary)
#     return np.mean(np.array(infected_ratio_list))

# %% [markdown]
# ### Perform n simulations
#
# Let's define an auxiliary function for performing NREP simulations

# %%
NREP = 100

# %%
def perform_n_iterations(g, len_g, MU, BETA, n=NREP):
    
    start_t = time.time()
    infected_ratio_list = np.zeros(NREP) # vector with avg infection ratio of each simulation
    
    for i in range(NREP):
        
        start_time = time.time()
        state = np.array(np.random.binomial(1, P0, size=len_g), dtype=np.int8) # initial state
        
        infected_ratio_list[i] = simulation(g, len_g, state, MU, BETA)
        print("Time required by simulation {}: {} seconds".format(i+1, time.time()-start_time))
    print("\nTime required by {} simulations: {} seconds\n\n".format(n, time.time() - start_t))
    
    return np.mean(infected_ratio_list) # return average of averages over 100 iterations

# %% [markdown]
# ### Iterate over β
# We need now to iterate over different beta values

# %%
def iterate_over_beta(g, len_g, MU, beta_list): # notice that MU is given
    # avg ρ for each β
    avg_over_beta = np.zeros(len(beta_list))
    
    for i, beta in enumerate(beta_list):
        print("Calculate value for beta = {} (mu = {})".format(beta, MU))
        avg_over_beta[i] = perform_n_iterations(g, len_g, MU, beta, NREP) 
        
    # returns the value for each beta value given the MU value
    return avg_over_beta

# %% [markdown]
# # Example

# %% [markdown]
# ## Network

# %%
len_g = 500
g = ig.Graph.Barabasi(len_g, 5)

# %% [markdown]
# ### Some network descriptors
# We use networkx

# %%
import networkx as nx

# read the net as a networkx network
#path = os.path.join("nets", network_f, network_name + '.net')
#G = nx.read_pajek(path)

A = g.get_edgelist()
G = nx.Graph(A)

nnodes = G.number_of_nodes()
print("Number of nodes: {}".format(nnodes))
#G.nodes()

print("Number of edges: {}".format(G.number_of_edges()))
#G.edges()

degrees_values = [val for key,val in G.degree()] # degree for each node
#degrees_values

print("Min degree: {}".format(np.min(degrees_values)))
print("Max degree: {}".format(np.max(degrees_values)))
print("Avg degree: {}".format(round(np.mean(degrees_values), 4)))
#G = nx.Graph(G)

print("Clustering: {}".format(round(nx.average_clustering(G), 4)))
print("Assortativity: {}".format(round(nx.degree_assortativity_coefficient(G), 4)))
if nx.is_connected(G):
    print("Avg path length: {}".format(round(nx.average_shortest_path_length(G), 4)))
    print("Diameter: {}".format(nx.diameter(G)))
# Out:
# Number of nodes: 500
# Number of edges: 2485
# Min degree: 5
# Max degree: 81
# Avg degree: 9.94
# Clustering: 0.0655
# Assortativity: -0.0461
# Avg path length: 2.7687
# Diameter: 5

# %% [markdown]
# ### Plot of the network

# %%
pos = nx.kamada_kawai_layout(G)
# perform the drawing, by using the node coordinates calculated above

# select node size depending on the network size
if nnodes >= 2000:
    node_size = 30
elif nnodes >= 1000 and nnodes < 2000:
    node_size = 50
elif nnodes >= 500 and nnodes  < 1000:
    node_size =  150
else:
    node_size = 250
    
#p_i = os.path.join("images", network_f, network_name)
#if not os.path.exists(p_i):
#    os.makedirs(p_i)
    
nx.draw(G, pos=pos, node_size=node_size, width=0.4, edge_color='0.3', node_color='red')

#plt.savefig(os.path.join(p_i, network_name + '_intro-plot.png')) # to save the plot

# %% [markdown]
# ### Save network

# %%
#g.write_pajek("example")

# %% [markdown]
# ## Simulation

# %%
P0 = 0.2

# %% [markdown]
# ### Adjust parameters TMAX and TTRANS by performing a simulation
# For these two parameters it would be better to adjust them using a simulation: we plot
# ρ(t) to be sure that, after TTrans time steps, the value of ρ has not a clear tendency to
# increase or decrease, despite the oscillations due to the stochastic nature of the
# simulation process.

# %%
# TODO

# %% [markdown]
# ### Lists

# %%
STEP_BETA = 0.02

mu_list = [0.1, 0.5, 0.9]
beta_list = np.arange(0.00, 1.00, STEP_BETA)

# %%
len(beta_list) # SHOULD BE AT LEAST 51 VALUES WITH deltaB = 0.02
# Out:
# 50

# %%
beta_list
# Out:
# array([0.  , 0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18, 0.2 ,
#        0.22, 0.24, 0.26, 0.28, 0.3 , 0.32, 0.34, 0.36, 0.38, 0.4 , 0.42,
#        0.44, 0.46, 0.48, 0.5 , 0.52, 0.54, 0.56, 0.58, 0.6 , 0.62, 0.64,
#        0.66, 0.68, 0.7 , 0.72, 0.74, 0.76, 0.78, 0.8 , 0.82, 0.84, 0.86,
#        0.88, 0.9 , 0.92, 0.94, 0.96, 0.98])

# %% [markdown]
# ### Perform the simulation

# %%
values_per_mu = []
start_time = time.time()

for mu in mu_list:
    print("Calculate value for mu = {}\n".format(mu))
    values_per_mu.append(iterate_over_beta(g, len_g, mu, beta_list)) 
    
print("Total required time: {} seconds".format(time.time() - start_time))
# Out:
# Calculate value for mu = 0.1
#
# Calculate value for beta = 0.0
# Time required by simulation 1: 0.431302547454834 seconds
# Time required by simulation 2: 0.44668054580688477 seconds
# Time required by simulation 3: 0.426349401473999 seconds
# Time required by simulation 4: 0.3807389736175537 seconds
# Time required by simulation 5: 0.3718428611755371 seconds
# Time required by simulation 6: 0.37532758712768555 seconds
# Time required by simulation 7: 0.36999082565307617 seconds
# Time required by simulation 8: 0.3756077289581299 seconds
# Time required by simulation 9: 0.3008537292480469 seconds
# Time required by simulation 10: 0.3047139644622803 seconds
# Time required by simulation 11: 0.3583512306213379 seconds
# Time required by simulation 12: 0.3697376251220703 seconds
# Time required by simulation 13: 0.4134676456451416 seconds
# Time required by simulation 14: 0.38529276847839355 seconds
# Time required by simulation 15: 0.44138097763061523 seconds
# Time required by simulation 16: 0.4090285301208496 seconds
# Time required by simulation 17: 0.41896724700927734 seconds
# Time required by simulation 18: 0.4107532501220703 seconds
# Time required by simulation 19: 0.4152066707611084 seconds
# Time required by simulation 20: 0.4041767120361328 seconds
# Time required by simulation 21: 0.3797588348388672 seconds
# Time required by simulation 22: 0.3609592914581299 seconds
# Time required by simulation 23: 0.38710904121398926 seconds
# Time required by simulation 24: 0.40294885635375977 seconds
# Time required by simulation 25: 0.3862020969390869 seconds
# Time required by simulation 26: 0.4321119785308838 seconds
# Time required by simulation 27: 0.3869338035583496 seconds
# Time required by simulation 28: 0.3826172351837158 seconds
# Time required by simulation 29: 0.35933852195739746 seconds
# Time required by simulation 30: 0.4009678363800049 seconds
# Time required by simulation 31: 0.3768279552459717 seconds
# Time required by simulation 32: 0.40421295166015625 seconds
# Time required by simulation 33: 0.37776851654052734 seconds
# Time required by simulation 34: 0.341533899307251 seconds
# Time required by simulation 35: 0.35979723930358887 seconds
# Time required by simulation 36: 0.38254880905151367 seconds
# Time required by simulation 37: 0.35617876052856445 seconds
# Time required by simulation 38: 0.4556870460510254 seconds
# Time required by simulation 39: 0.38498401641845703 seconds
# Time required by simulation 40: 0.3894844055175781 seconds
# Time required by simulation 41: 0.3907921314239502 seconds
# Time required by simulation 42: 0.38727474212646484 seconds
# Time required by simulation 43: 0.34623289108276367 seconds
# Time required by simulation 44: 0.3426632881164551 seconds
# Time required by simulation 45: 0.37195277214050293 seconds
# Time required by simulation 46: 0.36902952194213867 seconds
# Time required by simulation 47: 0.33011722564697266 seconds
# Time required by simulation 48: 0.3533012866973877 seconds
# Time required by simulation 49: 0.36066508293151855 seconds
# Time required by simulation 50: 0.3530418872833252 seconds
# Time required by simulation 51: 0.3142108917236328 seconds
# Time required by simulation 52: 0.34651827812194824 seconds
# Time required by simulation 53: 0.3428211212158203 seconds
# Time required by simulation 54: 0.3225736618041992 seconds
# Time required by simulation 55: 0.3797464370727539 seconds
# Time required by simulation 56: 0.3752474784851074 seconds
# Time required by simulation 57: 0.3812422752380371 seconds
# Time required by simulation 58: 0.37107157707214355 seconds
# Time required by simulation 59: 0.3836085796356201 seconds
# Time required by simulation 60: 0.37209153175354004 seconds
# Time required by simulation 61: 0.3732187747955322 seconds
# Time required by simulation 62: 0.3803842067718506 seconds
# Time required by simulation 63: 0.3792896270751953 seconds
# Time required by simulation 64: 0.3963179588317871 seconds
# Time required by simulation 65: 0.3812294006347656 seconds
# Time required by simulation 66: 0.3948028087615967 seconds
# Time required by simulation 67: 0.37830257415771484 seconds
# Time required by simulation 68: 0.3597264289855957 seconds
# Time required by simulation 69: 0.3486039638519287 seconds
# Time required by simulation 70: 0.32504987716674805 seconds
# Time required by simulation 71: 0.36696743965148926 seconds
# Time required by simulation 72: 0.3728170394897461 seconds
# Time required by simulation 73: 0.36136436462402344 seconds
# Time required by simulation 74: 0.3827829360961914 seconds
# Time required by simulation 75: 0.38929009437561035 seconds
# Time required by simulation 76: 0.3540515899658203 seconds
# Time required by simulation 77: 0.387969970703125 seconds
# Time required by simulation 78: 0.37897825241088867 seconds
# Time required by simulation 79: 0.3650217056274414 seconds
# Time required by simulation 80: 0.4109015464782715 seconds
# Time required by simulation 81: 0.38129448890686035 seconds
# Time required by simulation 82: 0.3657097816467285 seconds
# Time required by simulation 83: 0.37866663932800293 seconds
# Time required by simulation 84: 0.37819719314575195 seconds
# Time required by simulation 85: 0.39472365379333496 seconds
# Time required by simulation 86: 0.35985779762268066 seconds
# Time required by simulation 87: 0.40258288383483887 seconds
# Time required by simulation 88: 0.3741331100463867 seconds
# Time required by simulation 89: 0.3869802951812744 seconds
# Time required by simulation 90: 0.39223456382751465 seconds
# Time required by simulation 91: 0.39695048332214355 seconds
# Time required by simulation 92: 0.396914005279541 seconds
# Time required by simulation 93: 0.3823986053466797 seconds
# Time required by simulation 94: 0.3337242603302002 seconds
# Time required by simulation 95: 0.3251039981842041 seconds
# Time required by simulation 96: 0.348984956741333 seconds
# Time required by simulation 97: 0.4225759506225586 seconds
# Time required by simulation 98: 0.40159058570861816 seconds
# Time required by simulation 99: 0.41588783264160156 seconds
# Time required by simulation 100: 0.39394569396972656 seconds
#
# Time required by 100 simulations: -37.84197998046875 seconds
#
#
# Calculate value for beta = 0.02
# Time required by simulation 1: 0.22641372680664062 seconds
# Time required by simulation 2: 0.2373640537261963 seconds
# Time required by simulation 3: 0.21861958503723145 seconds
# Time required by simulation 4: 0.19081592559814453 seconds
# Time required by simulation 5: 0.1934812068939209 seconds
# Time required by simulation 6: 0.1934826374053955 seconds
# Time required by simulation 7: 0.1900160312652588 seconds
# Time required by simulation 8: 0.2295975685119629 seconds
# Time required by simulation 9: 0.23632049560546875 seconds
# Time required by simulation 10: 0.26285338401794434 seconds
# Time required by simulation 11: 0.2353649139404297 seconds
# Time required by simulation 12: 0.2242293357849121 seconds
# Time required by simulation 13: 0.21135449409484863 seconds
# Time required by simulation 14: 0.19248580932617188 seconds
# Time required by simulation 15: 0.19647479057312012 seconds
# Time required by simulation 16: 0.18655157089233398 seconds
# Time required by simulation 17: 0.19149541854858398 seconds
# Time required by simulation 18: 0.22518491744995117 seconds
# Time required by simulation 19: 0.23693251609802246 seconds
# Time required by simulation 20: 0.21543145179748535 seconds
# Time required by simulation 21: 0.2005167007446289 seconds
# Time required by simulation 22: 0.21038460731506348 seconds
# Time required by simulation 23: 0.22239208221435547 seconds
# Time required by simulation 24: 0.2033557891845703 seconds
# Time required by simulation 25: 0.21985697746276855 seconds
# Time required by simulation 26: 0.229583740234375 seconds
# Time required by simulation 27: 0.19715285301208496 seconds
# Time required by simulation 28: 0.2128617763519287 seconds
# Time required by simulation 29: 0.2014622688293457 seconds
# Time required by simulation 30: 0.18949127197265625 seconds
# Time required by simulation 31: 0.19057559967041016 seconds
# Time required by simulation 32: 0.20046472549438477 seconds
# Time required by simulation 33: 0.19378948211669922 seconds
# Time required by simulation 34: 0.1971893310546875 seconds
# Time required by simulation 35: 0.1974484920501709 seconds
# Time required by simulation 36: 0.1994762420654297 seconds
# Time required by simulation 37: 0.2204303741455078 seconds
# Time required by simulation 38: 0.2254772186279297 seconds
# Time required by simulation 39: 0.20447421073913574 seconds
# Time required by simulation 40: 0.1962418556213379 seconds
# Time required by simulation 41: 0.2165088653564453 seconds
# Time required by simulation 42: 0.19747447967529297 seconds
# Time required by simulation 43: 0.22340035438537598 seconds
# Time required by simulation 44: 0.20729899406433105 seconds
# Time required by simulation 45: 0.21236276626586914 seconds
# Time required by simulation 46: 0.2077944278717041 seconds
# Time required by simulation 47: 0.23446917533874512 seconds
# Time required by simulation 48: 0.20593690872192383 seconds
# Time required by simulation 49: 0.22137093544006348 seconds
# Time required by simulation 50: 0.227370023727417 seconds
# Time required by simulation 51: 0.23111724853515625 seconds
# Time required by simulation 52: 0.214585542678833 seconds
# Time required by simulation 53: 0.20445537567138672 seconds
# Time required by simulation 54: 0.20245718955993652 seconds
# Time required by simulation 55: 0.2107865810394287 seconds
# Time required by simulation 56: 0.2276453971862793 seconds
# Time required by simulation 57: 0.21873021125793457 seconds
# Time required by simulation 58: 0.19547080993652344 seconds
# Time required by simulation 59: 0.18853020668029785 seconds
# Time required by simulation 60: 0.204695463180542 seconds
# Time required by simulation 61: 0.1954655647277832 seconds
# Time required by simulation 62: 0.21372675895690918 seconds
# Time required by simulation 63: 0.21470952033996582 seconds
# Time required by simulation 64: 0.20051336288452148 seconds
# Time required by simulation 65: 0.19853639602661133 seconds
# Time required by simulation 66: 0.19747185707092285 seconds
# Time required by simulation 67: 0.19526290893554688 seconds
# Time required by simulation 68: 0.18065452575683594 seconds
# Time required by simulation 69: 0.18305349349975586 seconds
# Time required by simulation 70: 0.201859712600708 seconds
# Time required by simulation 71: 0.21110296249389648 seconds
# Time required by simulation 72: 0.23875045776367188 seconds
# Time required by simulation 73: 0.2598912715911865 seconds
# Time required by simulation 74: 0.23468828201293945 seconds
# Time required by simulation 75: 0.22224688529968262 seconds
# Time required by simulation 76: 0.19248723983764648 seconds
# Time required by simulation 77: 0.2144629955291748 seconds
# Time required by simulation 78: 0.2521359920501709 seconds
# Time required by simulation 79: 0.24003314971923828 seconds
# Time required by simulation 80: 0.23466110229492188 seconds
# Time required by simulation 81: 0.25075411796569824 seconds
# Time required by simulation 82: 0.18990612030029297 seconds
# Time required by simulation 83: 0.18653345108032227 seconds
# Time required by simulation 84: 0.2044515609741211 seconds
# Time required by simulation 85: 0.1875002384185791 seconds
# Time required by simulation 86: 0.2305128574371338 seconds
# Time required by simulation 87: 0.1914680004119873 seconds
# Time required by simulation 88: 0.24648284912109375 seconds

# %%
values_per_mu

# %% [markdown]
# ### Final plot

# %%
for i in range(len(mu_list)):
    plt.plot(beta_list, values_per_mu[i], label=r'$\mu$' + '={}'.format(mu_list[i]))
    plt.title(r'$\rho$' + ' in function of ' + r'$\beta$', fontsize=15)
    plt.xlabel(r'$\beta$', fontsize=15)
    plt.ylabel(r'$\rho$', fontsize=15)
    plt.legend(loc='lower right')
    plt.tight_layout()
    plt.style.use('seaborn-darkgrid')
